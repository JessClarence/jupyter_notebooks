# %%
# importing the required module
import matplotlib.pyplot as plt
  
# no optimization
x = [0.02, 0.2, 2, 20]
y = [10,100,1000, 10000]

x1 = [0.03, 0.3, 3, 30]
y1= [10,100,1000, 10000]

x2 = [0.04, 0.4, 4, 40]
y2 = [10,100,1000, 10000]
# -O1
x3 = [0.05, 0.5, 5, 50]
y3 = [10,100,1000, 10000]
# -O2
x4 = [0.06, 0.6, 6, 60]
y4 = [10,100,1000, 10000]
# -03
x5 = [0.07, 0.7, 7, 70]
y5 = [10,100,1000, 10000]


# plotting the points 
plt.plot(x, y, label = "combine2")
plt.plot(x1, y1, label = "combine3")
plt.plot(x2, y2, label = "combine4")
plt.plot(x3, y3, label = "combine5x2")
plt.plot(x4, y4, label = "combine5x3")
plt.plot(x5, y5, label = "combine6")
# naming the x axis
plt.xlabel('Time in Seconds')
# naming the y axis
plt.ylabel('vector size')
  
# giving a title to my graph
  
# function to show the plot
plt.legend()
plt.show()
